# %% [markdown]
# # Step 1 - Install the required dependencies and make sure the python version is 3.10 and above

# %%
# %pip install zenoml
# Out:
# Requirement already satisfied: zenoml in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (0.6.4)
# Requirement already satisfied: fastapi<0.101.0,>=0.95.1 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from zenoml) (0.100.1)
# Requirement already satisfied: inquirer<4.0.0,>=3.1.2 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from zenoml) (3.4.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.6 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from zenoml) (1.6.0)
# Requirement already satisfied: opentsne<1.1.0,>=0.7.1 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from zenoml) (1.0.2)
# Requirement already satisfied: pandas<3.0.0,>=2.0.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from zenoml) (2.2.3)
# Requirement already satisfied: pathos<0.4.0,>=0.3.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from zenoml) (0.3.2)
# Requirement already satisfied: pydantic<2.0.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from zenoml) (1.10.21)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from zenoml) (2.32.3)
# Requirement already satisfied: setuptools in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from zenoml) (65.5.0)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from zenoml) (2.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from zenoml) (4.67.1)
# Requirement already satisfied: uvicorn<0.24,>=0.22 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from zenoml) (0.23.2)
# Requirement already satisfied: websockets<12.0,>=11.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from zenoml) (11.0.3)
# Requirement already satisfied: zeno-sliceline<0.0.2,>=0.0.1 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from zenoml) (0.0.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from fastapi<0.101.0,>=0.95.1->zenoml) (0.27.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from fastapi<0.101.0,>=0.95.1->zenoml) (4.12.2)
# Requirement already satisfied: blessed>=1.19.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from inquirer<4.0.0,>=3.1.2->zenoml) (1.20.0)
# Requirement already satisfied: editor>=1.6.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from inquirer<4.0.0,>=3.1.2->zenoml) (1.6.6)
# Requirement already satisfied: readchar>=4.2.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from inquirer<4.0.0,>=3.1.2->zenoml) (4.2.1)
# Requirement already satisfied: numpy>=1.16.6 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from opentsne<1.1.0,>=0.7.1->zenoml) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.20 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from opentsne<1.1.0,>=0.7.1->zenoml) (1.6.1)
# Requirement already satisfied: scipy in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from opentsne<1.1.0,>=0.7.1->zenoml) (1.15.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from pandas<3.0.0,>=2.0.0->zenoml) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from pandas<3.0.0,>=2.0.0->zenoml) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from pandas<3.0.0,>=2.0.0->zenoml) (2025.1)
# Requirement already satisfied: ppft>=1.7.6.8 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from pathos<0.4.0,>=0.3.0->zenoml) (1.7.6.9)
# Requirement already satisfied: dill>=0.3.8 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from pathos<0.4.0,>=0.3.0->zenoml) (0.3.8)
# Requirement already satisfied: pox>=0.3.4 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from pathos<0.4.0,>=0.3.0->zenoml) (0.3.5)
# Requirement already satisfied: multiprocess>=0.70.16 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from pathos<0.4.0,>=0.3.0->zenoml) (0.70.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->zenoml) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->zenoml) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->zenoml) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->zenoml) (2025.1.31)
# Requirement already satisfied: click>=7.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from uvicorn<0.24,>=0.22->zenoml) (8.1.8)
# Requirement already satisfied: h11>=0.8 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from uvicorn<0.24,>=0.22->zenoml) (0.14.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from blessed>=1.19.0->inquirer<4.0.0,>=3.1.2->zenoml) (0.2.13)
# Requirement already satisfied: six>=1.9.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from blessed>=1.19.0->inquirer<4.0.0,>=3.1.2->zenoml) (1.17.0)
# Requirement already satisfied: runs in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from editor>=1.6.0->inquirer<4.0.0,>=3.1.2->zenoml) (1.2.2)
# Requirement already satisfied: xmod in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from editor>=1.6.0->inquirer<4.0.0,>=3.1.2->zenoml) (1.8.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from scikit-learn>=0.20->opentsne<1.1.0,>=0.7.1->zenoml) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from scikit-learn>=0.20->opentsne<1.1.0,>=0.7.1->zenoml) (3.5.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from starlette<0.28.0,>=0.27.0->fastapi<0.101.0,>=0.95.1->zenoml) (4.8.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.101.0,>=0.95.1->zenoml) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.101.0,>=0.95.1->zenoml) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install datasets
# %pip install transformers
# %pip install tqdm
# Out:
# Requirement already satisfied: datasets in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (3.2.0)
# Requirement already satisfied: filelock in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from datasets) (19.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from datasets) (3.11.11)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: packaging in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from aiohttp->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: transformers in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (4.48.2)
# Requirement already satisfied: filelock in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (from requests->transformers) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tqdm in /Users/yhong3/.pyenv/versions/3.10.15/envs/MLIP/lib/python3.10/site-packages (4.67.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python --version
# Out:
# Python 3.10.15

# %% [markdown]
# # Step 2 - Load a dataset from Hugging Face

# %%
from datasets import load_dataset
import pandas as pd

ds = load_dataset("cardiffnlp/tweet_eval", "sentiment")
df = pd.DataFrame(ds["test"]).head(500)
df.head(5)
# Out:
#                                                 text  label
# 0  @user @user what do these '1/2 naked pics' hav...      1
# 1  OH: “I had a blue penis while I was this” [pla...      1
# 2  @user @user That's coming, but I think the vic...      1
# 3  I think I may be finally in with the in crowd ...      2
# 4  @user Wow,first Hugo Chavez and now Fidel Cast...      0

# %%
def label_map(x):
    if x == 0:
        return "negative"
    elif x == 1:
        return "neutral"
    elif x == 2:
        return "positive"
    return x


df["label"] = df["label"].map(label_map)

# %% [markdown]
# # Step 3 - Run model inference

# %% [markdown]
# Warning: This step is going to download two models of ~500MB each.
#
# **If you don't want to download the models, you can jump to step 4 and use the provided data in the repo instead.**

# %% [markdown]
# ### Run inference with roberta

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline(
    "text-classification", model="cardiffnlp/twitter-roberta-base-sentiment-latest"
)
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use mps:0

# %%
import tqdm

results = []
texts = df["text"].to_list()

## Depending on your machine, this should take around 1 minute
for text in tqdm.tqdm(texts):
    results.append(pipe(text))
# Out:
# 100%|██████████| 500/500 [00:12<00:00, 40.14it/s]

# %%
df["roberta"] = [r[0]["label"] for r in results]
df["roberta_score"] = [r[0]["score"] for r in results]

# %% [markdown]
# ### Run inference with gpt2

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline(
    "text-classification", model="LYTinn/finetuning-sentiment-model-tweet-gpt2"
)
# Out:
# Device set to use mps:0

# %%
import tqdm

results = []
texts = df["text"].to_list()

## Depending on your machine, this should take around 1 minute
for text in tqdm.tqdm(texts):
    results.append(pipe(text))
# Out:
# 100%|██████████| 500/500 [00:09<00:00, 51.32it/s]

# %%
df["gpt2"] = [r[0]["label"] for r in results]
df["gpt2_score"] = [r[0]["score"] for r in results]


## map labels back
def label_map(x):
    if x == "LABEL_0":
        return "negative"
    elif x == "LABEL_1":
        return "neutral"
    elif x == "LABEL_2":
        return "positive"
    return x


df["gpt2"] = df["gpt2"].map(label_map)

# %% [markdown]
# # Step 4 - Pre-processing data and add additional columns

# %%
## If you skip the model inference, uncomment the code below and load the provided data

# df = pd.read_csv('tweets.csv')

# %%
df["input_length"] = df["text"].str.len()

# %% [markdown]
# # Step 5 - Start Zeno for interactive slicing
#
# In this step, you need to create 5 slices in the Zeno interface and derive meaningful insights.
#
# As a starting point, try to create the two slices we provide:
#
# 1. Tweets with hashtags
# 2. Tweets with strong positive words (e.g., love) -- you can determine the exact words

# %% [markdown]
# Creating slices in Zeno is straightforward: Just click on the '+' button for 'create a new slice', and you can define the slice using existing column attributes, with simple value macthing or even regular expression.
#
# ![image.png](images/image.png)
#
# There are more fun features in Zeno, including interactive metadata & model comparison -- feel free to check the teaser video in [README](https://github.com/zeno-ml/zeno) of the Zeno repository.

# %%
## Execute the code here to start a local Zeno server

from zeno import zeno

from zeno.api import model, distill, metric
from zeno.api import ModelReturn, MetricReturn, DistillReturn, ZenoOptions


@model
def load_model(model_name):

    def pred(df, ops: ZenoOptions):
        out = df[model_name]
        return ModelReturn(model_output=out)

    return pred


@distill
def label_match(df, ops: ZenoOptions):
    results = (df[ops.label_column] == df[ops.output_column]).to_list()
    return DistillReturn(distill_output=results)


@metric
def accuracy(df, ops: ZenoOptions):
    avg = df[ops.distill_columns["label_match"]].mean()
    return MetricReturn(metric=avg)


zeno(
    {
        "metadata": df,  # Pandas DataFrame with a row for each instance
        "view": "text-classification",  # The type of view for this data/task
        "data_column": "text",
        "label_column": "label",
        "functions": [load_model, label_match, accuracy],
        "models": ["roberta", "gpt2"],
        "port": 8233,
    }
)
# Out:
# WARNING: no id_column specified, using index as id_column. If you are using a data_column, suggest using it as id_column.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Zeno running on http://localhost:8233
# Running predistill functions
#
# Running inference
# Running postdistill functions
# Done processing
# /Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# /Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# /Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# /Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/uvicorn/middleware/proxy_headers.py", line 84, in __call__
#     return await self.app(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/routing.py", line 443, in handle
#     await self.app(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/routing.py", line 276, in handle
#     await self.app(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/routing.py", line 66, in app
#     response = await func(request)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/fastapi/routing.py", line 273, in app
#     raw_response = await run_endpoint_function(
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/fastapi/routing.py", line 192, in run_endpoint_function
#     return await run_in_threadpool(dependant.call, **values)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/concurrency.py", line 41, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func, *args)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2461, in run_sync_in_worker_thread
#     return await future
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 962, in run
#     result = context.run(func, *args)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/zeno/server.py", line 153, in calculate_histogram_metrics
#     return histogram_metrics(zeno.df, zeno.calculate_metric, req)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/zeno/processing/histogram_processing.py", line 140, in histogram_metrics
#     metric = metric_fn(df_filt, req.model, req.metric)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/zeno/backend.py", line 575, in calculate_metric
#     return self.metric_functions[metric](df, local_ops).metric
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/zeno/api.py", line 156, in _wrapper
#     return func(*args, **kwargs)
#   File "/var/folders/ys/yfdnq0l94cl3g1s0q8p1m2gc0000gq/T/ipykernel_11350/2578381498.py", line 28, in accuracy
#     return MetricReturn(metric=avg)
#   File "pydantic/main.py", line 347, in pydantic.main.BaseModel.__init__
# pydantic.error_wrappers.ValidationError: 1 validation error for MetricReturn
# metric
#   value is not a valid float (type=type_error.float)
# /Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# /Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# /Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# /Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/zeno/processing/histogram_processing.py:95: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   filt_df.groupby([pd.cut(filt_df[str(col)], bucs)])  # type: ignore
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/uvicorn/protocols/http/h11_impl.py", line 408, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/uvicorn/middleware/proxy_headers.py", line 84, in __call__
#     return await self.app(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/routing.py", line 443, in handle
#     await self.app(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/fastapi/applications.py", line 289, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/applications.py", line 122, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/middleware/errors.py", line 184, in __call__
#     raise exc
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/middleware/errors.py", line 162, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 79, in __call__
#     raise exc
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 68, in __call__
#     await self.app(scope, receive, sender)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 20, in __call__
#     raise e
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/fastapi/middleware/asyncexitstack.py", line 17, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/routing.py", line 718, in __call__
#     await route.handle(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/routing.py", line 276, in handle
#     await self.app(scope, receive, send)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/routing.py", line 66, in app
#     response = await func(request)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/fastapi/routing.py", line 273, in app
#     raw_response = await run_endpoint_function(
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/fastapi/routing.py", line 192, in run_endpoint_function
#     return await run_in_threadpool(dependant.call, **values)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/starlette/concurrency.py", line 41, in run_in_threadpool
#     return await anyio.to_thread.run_sync(func, *args)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2461, in run_sync_in_worker_thread
#     return await future
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 962, in run
#     result = context.run(func, *args)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/zeno/server.py", line 153, in calculate_histogram_metrics
#     return histogram_metrics(zeno.df, zeno.calculate_metric, req)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/zeno/processing/histogram_processing.py", line 140, in histogram_metrics
#     metric = metric_fn(df_filt, req.model, req.metric)
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/zeno/backend.py", line 575, in calculate_metric
#     return self.metric_functions[metric](df, local_ops).metric
#   File "/Users/yhong3/.pyenv/versions/MLIP/lib/python3.10/site-packages/zeno/api.py", line 156, in _wrapper
#     return func(*args, **kwargs)
#   File "/var/folders/ys/yfdnq0l94cl3g1s0q8p1m2gc0000gq/T/ipykernel_11350/2578381498.py", line 28, in accuracy
#     return MetricReturn(metric=avg)
#   File "pydantic/main.py", line 347, in pydantic.main.BaseModel.__init__
# pydantic.error_wrappers.ValidationError: 1 validation error for MetricReturn
# metric
#   value is not a valid float (type=type_error.float)

# %% [markdown]
# After running the code above, you should be able to access Zeno in http://localhost:8231

# %% [markdown]
# After successfully creating the two slices, come up with three *additional* slices you want to check and **create** the slices in the Zeno interface.
#
# There are two directions to identify useful slices:
# - Top-down: Think about what kinds of things the model can struggle with, and come up with some slices.
# - Bottom-up: Look at model (mis-)predictions, come up with hypotheses, and translate them into data slices.
#
# 3. [YOUR CHOICE]
# 4. [YOUR CHOICE]
# 5. [YOUR CHOICE]

# %%
## Write down descriptions of additional slices you created

custom_slice_descriptions = [
    "Tweets with negative word 'no'",
    "Tweets that mention other users (with @user)"
    "Tweets with external url links (with 'http')",
]

# %% [markdown]
# # Step 6 - Write down three addition data slices you want to create but do not have the metadata for slicing

# %% [markdown]
# In the previous step, you might have already come up with some slices you wanted to create but found it hard to do with existing metadata. Write down three of such slices in this step.
#
# Example:
# - I want to create a slice on tweets using slangs
# - I want to create a slice on non-English tweets (if any)

# %%
## Write down three additional data slices here:

additional_slice_descriptions = [
    "I want to create a slice on tweets that mention people from minority groups",
    "I want to create a slice on tweets that are sarcastic",
    "I want to create a slice on tweets that are sent from a certain country/district",
]

# %% [markdown]
# # Step 7 - Generate more test cases with Large Language Models

# %% [markdown]
# Select one slice from the three you wrote down and generate **10 test cases** using LLMs, which can include average case, boundary case, or difficult case.
#
# Your input can be in the following format:
#
# > Examples:
# > - OH: “I had a blue penis while I was this” [playing with Google Earth VR]
# > - @user @user That’s coming, but I think the victims are going to be Medicaid recipients.
# > - I think I may be finally in with the in crowd #mannequinchallenge  #grads2014 @user
# >
# > Generate more tweets using slangs.
#
# The first part of **Examples** conditions the LLM on the style, length, and content of examples. The second part of **Instructions** instructs what kind of examples you want LLM to generate.
#
# Use our provided GPTs to start the task: [llm-based-test-case-generator](https://chatgpt.com/g/g-982cylVn2-llm-based-test-case-generator). If you do not have access to GPTs, use the plain ChatGPT or other LLM providers you have access to instead.

# %%
## Write down the slice you select

slice_description = "Tweets that mention people from minority groups"

prompt = """Examples:
- OH: “I had a blue penis while I was this” [playing with Google Earth VR]
- @user @user That’s coming, but I think the victims are going to be Medicaid recipients.
- I think I may be finally in with the in crowd #mannequinchallenge  #grads2014 @user

Generate more tweets that mention people from minority groups."""

## Write down all generated test cases here

generated_test_cases = [
    "Just saw an incredible spoken word performance by a young Indigenous poet—powerful and moving. #RepresentationMatters",
    "My professor, a brilliant Black woman, just dropped some serious knowledge about systemic bias in AI. Mind blown.",
    "So proud of my cousin for opening the first Latina-owned bookstore in our city! Representation in literature matters. 📚✨",
    "Watching this documentary on trans activists fighting for healthcare rights—so much respect for their resilience.",
    "Shoutout to my Sikh neighbor who volunteers every weekend to feed the unhoused community. True community hero.",
    "The fact that Native languages are being revitalized despite centuries of erasure is a testament to Indigenous strength.",
    "Seeing Muslim women thriving in STEM fields despite all the barriers is truly inspiring.",
    "My deaf coworker just gave an incredible presentation in ASL with an interpreter, and the whole team was so engaged.",
    "Just learned about the Black Wall Street massacre in detail—why wasn’t this taught in school?!",
    "Watching this panel of Asian American filmmakers discuss their struggles in the industry—so much talent and resilience!"
]
# Out:
# Zeno running on http://localhost:8233
#
# Running postdistill functions
# Done processing
